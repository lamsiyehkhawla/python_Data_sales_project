# %% [markdown]
# <H1>Step 1: Recueillir les données (Data Collection)</H1>

# %%
import pandas as pd
#charger le fichier Excel 
file_path= '/home/lamsiyehkhawla/Downloads/sales.xlsx'
sales_df=pd.read_excel(file_path)
print("Colonnes du fichier :", sales_df.columns.tolist())
# Out:
# Colonnes du fichier : ['OrderNumber', 'OrderDate', 'Ship Date', 'Customer Name Index', 'Channel', 'Currency Code', 'Warehouse Code', 'Delivery Region Index', 'Product Description Index', 'Order Quantity', 'Unit Selling Price', 'Unit Cost']

# %%
#charger le fichier Excel 
file_path= '/home/lamsiyehkhawla/Downloads/sales.xlsx'
sales_df=pd.read_excel(file_path)

# Netooyage des colonnes
sales_df.columns = sales_df.columns.str.strip()
#renommer les colonnes à utiliser 
sales_df= sales_df.rename(columns={
    'OrderDate': 'Date',
    'Order Quantity': 'Order_Quantity',
    'Unit Selling Price': 'Unit_Selling_Price',
    'Unit Cost': 'Unit_cost',
    'Customer Name Index': 'Customer',
    'Product Description Index': 'Product',
    'Delivery Region Index': 'Region',
    'Channel' : 'Channel',
    
})
# Calculer les champs nécessaires 
sales_df['Sales']=sales_df['Order_Quantity'] * sales_df['Unit_Selling_Price']
sales_df['Cost'] = sales_df['Order_Quantity'] * sales_df['Unit_cost']
sales_df['Profit'] = sales_df['Sales'] - sales_df['Cost']
print(sales_df.head())
# Out:
#     OrderNumber       Date  Ship Date  Customer      Channel Currency Code  \
# 0   SO - 000225 2017-01-01 2017-01-13        28    Wholesale           NZD
# 1  SO - 0003378 2017-01-01 2017-01-06         7  Distributor           NZD
# 2  SO - 0003901 2017-01-01 2017-01-05        12    Wholesale           NZD
# 3  SO - 0005126 2017-01-01 2017-01-17         5    Wholesale           USD
# 4  SO - 0005614 2017-01-01 2017-01-07        27       Export           NZD
#
#   Warehouse Code  Region  Product  Order_Quantity  Unit_Selling_Price  \
# 0         AXW291      71       11               6              2499.1
# 1         AXW291      54        7              11              2351.7
# 2         AXW291      58       13               5              1728.6
# 3         AXW291      29        7               6               978.2
# 4         AXW291      31        6               7              2338.3
#
#    Unit_cost    Sales       Cost     Profit
# 0   1824.343  14994.6  10946.058   4048.542
# 1   1269.918  25868.7  13969.098  11899.602
# 2   1019.874   8643.0   5099.370   3543.630
# 3    684.740   5869.2   4108.440   1760.760
# 4   1028.852  16368.1   7201.964   9166.136

# %% [markdown]
# <H1> Step 2: Nettoyage et transformation (ETL)</H1>

# %%
#Supprimer les doublons
sales_df=sales_df.drop_duplicates()
print("Valeurs manquantes par colonne :")
print(sales_df.isna().sum())
sales_df = sales_df.dropna(subset=['Date','Sales','Profit','Cost','Order_Quantity'])
#Conversion de la colonne Date
sales_df['Date'] = pd.to_datetime(sales_df['Date'])
print(sales_df.dtypes)
# Out:
# Valeurs manquantes par colonne :
# OrderNumber           0
# Date                  0
# Ship Date             0
# Customer              0
# Channel               0
# Currency Code         0
# Warehouse Code        0
# Region                0
# Product               0
# Order_Quantity        0
# Unit_Selling_Price    0
# Unit_cost             0
# Sales                 0
# Cost                  0
# Profit                0
# dtype: int64
# OrderNumber                   object
# Date                  datetime64[ns]
# Ship Date             datetime64[ns]
# Customer                       int64
# Channel                       object
# Currency Code                 object
# Warehouse Code                object
# Region                         int64
# Product                        int64
# Order_Quantity                 int64
# Unit_Selling_Price           float64
# Unit_cost                    float64
# Sales                        float64
# Cost                         float64
# Profit                       float64
# dtype: object

# %% [markdown]
# <H1>Step 3: Créer un DataFrame des dates</H1>

# %%
#Extraire les dates min et max 
min_date = sales_df['Date'].min()
max_date = sales_df['Date'].max()

#Créer la table des dates 
#Genrer les ates entre la date min et max d'une maniere quotidienne 
date_range = pd.date_range(start=min_date, end=max_date,freq='D')
#DataFrame contiendra une seule colonne 'Date' qui contient toutes les dates générées dans date_range.
date_df = pd.DataFrame({'Date': date_range})
#Cela extrait l'année de chaque date dans la colonne 'Date' et la place dans une nouvelle colonne 'Year'.
date_df['Year'] = date_df['Date'].dt.year
#ela extrait le mois (sous forme de nombre de 1 à 12) et l'ajoute dans la colonne 'Month'
date_df['Month'] = date_df['Date'].dt.month
#Cela extrait le nom complet du mois (par exemple, "janvier", "février") et l'ajoute dans la colonne 
date_df['Month_Name'] = date_df['Date'].dt.strftime('%B')
#Cela détermine le trimestre de l'année (1, 2, 3 ou 4) et l'ajoute dans la colonne 'Quarter'.
date_df['Quarter'] = date_df['Date'].dt.quarter
#ela extrait le nom du jour de la semaine (par exemple, "lundi", "mardi") et l'ajoute dans la colonne 
date_df['Weekday'] = date_df['Date'].dt.day_name()

print(date_df.head())
# Out:
#         Date  Year  Month Month_Name  Quarter    Weekday
# 0 2017-01-01  2017      1    January        1     Sunday
# 1 2017-01-02  2017      1    January        1     Monday
# 2 2017-01-03  2017      1    January        1    Tuesday
# 3 2017-01-04  2017      1    January        1  Wednesday
# 4 2017-01-05  2017      1    January        1   Thursday

# %% [markdown]
# <h2> Ajouter les noms de ville</h2>

# %%
# Ajouter les noms de ville depuis la feuille 'regions'
regions_df = pd.read_excel(file_path, sheet_name='Regions')
regions_df.columns = regions_df.columns.str.strip()

# Fusion sur les index de région
sales_df = pd.merge(
    sales_df,
    regions_df[['Index', 'City']],
    left_on='Region',
    right_on='Index',
    how='left'
)
#Suppression de la colonne 'Index' dans sales_df
sales_df.drop(columns=['Index'], inplace=True)

# %% [markdown]
# <h2>Ajouter les noms de produits </h2>

# %%
# Ajouter les noms de produits depuis la feuille 'Products'
products_df = pd.read_excel(file_path, sheet_name='Products')
products_df.columns = products_df.columns.str.strip()

# Fusion sur les index de products
sales_df = pd.merge(
    sales_df,
    products_df[['Index', 'Product Name']],
    left_on='Product',
    right_on='Index',
    how='left'
)
#Suppression de la colonne 'Index' dans sales_df
sales_df.drop(columns=['Index'], inplace=True)
#Rename le Product Name by Product_Name
sales_df = sales_df.rename(columns={'Product Name': 'Product_Name'})

# %% [markdown]
# <h2>Ajout des noms des clients</h2>

# %%
#Ajout des noms des clients
customers_df = pd.read_excel(file_path, sheet_name='Customers')
customers_df.columns = customers_df.columns.str.strip()

# On convertit la colonne 'Customer' du DataFrame des ventes (sales_df)
# en chaîne de caractères pour s'assurer qu'elle soit au même format
# que la colonne équivalente dans l'autre DataFrame.
sales_df['Customer'] = sales_df['Customer'].astype(str)
# De même, on convertit la colonne 'Customer Index' du DataFrame des clients (customers_df)
# en chaîne de caractères pour faciliter les opérations de jointure (merge) ou de comparaison.
customers_df['Customer Index'] = customers_df['Customer Index'].astype(str)

# Fusion sur les index du customers
sales_df = pd.merge(
    sales_df,
    customers_df[['Customer Index', 'Customer Names']],
    left_on='Customer',
    right_on='Customer Index',
    how='left'
)

# Clean up
sales_df.drop(columns=['Customer Index'], inplace=True)
sales_df = sales_df.rename(columns={'Customer Names': 'Customer_Name'})
#Affichier si on vois clareimnt les noms des customers pas les indexs 
print(sales_df)
# Out:
#        OrderNumber       Date  Ship Date Customer      Channel Currency Code  \
# 0      SO - 000225 2017-01-01 2017-01-13       28    Wholesale           NZD
# 1     SO - 0003378 2017-01-01 2017-01-06        7  Distributor           NZD
# 2     SO - 0003901 2017-01-01 2017-01-05       12    Wholesale           NZD
# 3     SO - 0005126 2017-01-01 2017-01-17        5    Wholesale           USD
# 4     SO - 0005614 2017-01-01 2017-01-07       27       Export           NZD
# ...            ...        ...        ...      ...          ...           ...
# 7986  SO - 0005237 2019-12-12 2019-12-16       41    Wholesale           NZD
# 7987  SO - 0005477 2019-12-12 2019-12-27       28  Distributor           AUD
# 7988  SO - 0006936 2019-12-12 2019-12-27       30    Wholesale           NZD
# 7989  SO - 0007126 2019-12-12 2019-12-25        6  Distributor           USD
# 7990  SO - 0007668 2019-12-12 2019-12-25        4    Wholesale           NZD
#
#      Warehouse Code  Region  Product  Order_Quantity  Unit_Selling_Price  \
# 0            AXW291      71       11               6              2499.1
# 1            AXW291      54        7              11              2351.7
# 2            AXW291      58       13               5              1728.6
# 3            AXW291      29        7               6               978.2
# 4            AXW291      31        6               7              2338.3
# ...             ...     ...      ...             ...                 ...
# 7986         FLR025      93        9               7               261.3
# 7987         FLR025      56        2               7              1996.6
# 7988         FLR025      66        1               9              3912.8
# 7989         FLR025      31        5              10              1855.9
# 7990         FLR025      65       13              11              3959.7
#
#       Unit_cost    Sales       Cost     Profit              City  \
# 0      1824.343  14994.6  10946.058   4048.542  Queenstown-Lakes
# 1      1269.918  25868.7  13969.098  11899.602      Christchurch
# 2      1019.874   8643.0   5099.370   3543.630          Hamilton
# 3       684.740   5869.2   4108.440   1760.760            Timaru
# 4      1028.852  16368.1   7201.964   9166.136         Waitakere
# ...         ...      ...        ...        ...               ...
# 7986    107.133   1829.1    749.931   1079.169            Napier
# 7987   1477.484  13976.2  10342.388   3633.812      Christchurch
# 7988   2817.216  35215.2  25354.944   9860.256           Dunedin
# 7989   1113.540  18559.0  11135.400   7423.600         Waitakere
# 7990   2138.238  43556.7  23520.618  20036.082           Waimate
#
#       Customer_Name  Customer_Name
# 0        Dharma Ltd     Dharma Ltd
# 1           New Ltd        New Ltd
# 2          Medline        Medline
# 3      Procter Corp   Procter Corp
# 4        Wuxi Group     Wuxi Group
# ...             ...            ...
# 7986    Weimei Corp    Weimei Corp
# 7987     Dharma Ltd     Dharma Ltd
# 7988   S.S.S. Group   S.S.S. Group
# 7989  PEDIFIX, Corp  PEDIFIX, Corp
# 7990      ETUDE Ltd      ETUDE Ltd
#
# [7991 rows x 18 columns]

# %% [markdown]
# <H1>Step 4: Créer les mesures et indicateurs</H1>

# %%
#Creation d'une copy de sales_df 
sales_df_copy = sales_df.copy()

#Ajouter colonne annee et mois
sales_df_copy['Year'] = sales_df_copy['Date'].dt.year
sales_df_copy['Month'] = sales_df_copy['Date'].dt.month
sales_df_copy['Month_Name'] = sales_df_copy['Date'].dt.strftime('%B')


print(sales_df_copy[['Date','Year','Month','Month_Name','City','Product_Name']].head())
# Out:
#         Date  Year  Month Month_Name              City Product_Name  \
# 0 2017-01-01  2017      1    January  Queenstown-Lakes   Product 11
# 1 2017-01-01  2017      1    January      Christchurch    Product 7
# 2 2017-01-01  2017      1    January          Hamilton   Product 13
# 3 2017-01-01  2017      1    January            Timaru    Product 7
# 4 2017-01-01  2017      1    January         Waitakere    Product 6
#
#   Product_Name Product_Name
# 0   Product 11   Product 11
# 1    Product 7    Product 7
# 2   Product 13   Product 13
# 3    Product 7    Product 7
# 4    Product 6    Product 6

# %% [markdown]
# <H2>Total Sales</H2>

# %%
#Calcul du chiffre d'affaires total
total_sales = sales_df_copy['Sales'].sum()
#Affichage du chiffre d'affaires formaté avec 2 chiffres après la virgule
print(f"Total sales : {total_sales:.2f}")
# Out:
# Total sales : 154573140.60

# %% [markdown]
# <h2>Total Sales PY (Previous Year)</h2>

# %%
# contiendra un nouveau DataFrame avec deux colonnes Year et Sales
#Le résultat est un DataFrame propre où chaque ligne contient une année et le total des ventes pour cette année.
sales_by_year = sales_df_copy.groupby('Year')['Sales'].sum().reset_index()

print("Ventes par année")
print(sales_by_year)

#  Vérification si on a des données pour au moins 2 années
if len(sales_by_year) >= 2:
    # Si oui, on récupère les ventes de l'année en cours (dernière ligne)
    current_year_sales = sales_by_year.iloc[-1]['Sales']
    # Et les ventes de l'année précédente (avant-dernière ligne)
    prev_year_sales = sales_by_year.iloc[-2]['Sales']
else:
    # Sinon, on définit les ventes de l'année en cours comme étant celles de l'ensemble des ventes
    current_year_sales = total_sales
    # Et l'année précédente comme étant zéro (pas de données pour l'année précédente)
    prev_year_sales = 0
# Out:
# Ventes par année
#    Year       Sales
# 0  2017  52580534.7
# 1  2018  53463661.7
# 2  2019  48528944.2

# %% [markdown]
# <h2>Total Sales/PY Var</h2>

# %%
# Calcul de la différence de ventes entre l'année en cours et l'année précédente
sales_diff = current_year_sales - prev_year_sales
# Affichage de la différence de ventes
print(f"Difference ventes (année en cours - précédente) : {sales_diff:.2f} MAD")
# Out:
# Difference ventes (année en cours - précédente) : -4934717.50 MAD

# %% [markdown]
# <h2>Total Sales/PY Var %</h2>

# %%
#  Calcul de la variation en pourcentage des ventes
# On évite la division par zéro en vérifiant si les ventes de l'année précédente sont différentes de zéro
if prev_year_sales != 0:
    sales_var_pct = (sales_diff / prev_year_sales) * 100
else:
    sales_var_pct = 0

# Affichage de la variation en pourcentage des ventes par rapport à l'année précédente
print(f"Variation en % des ventes YOY : {sales_var_pct:.2f}%")
# Out:
# Variation en % des ventes YOY : -9.23%

# %% [markdown]
# <h2>Total Order Quantity</h2>

# %%
total_orders =sales_df_copy['Order_Quantity'].sum()
print(f"Quantité totale commandée : {total_orders}")
# Out:
# Quantité totale commandée : 67579

# %% [markdown]
# <h2>Total Profit</h2>

# %%
#  Calcul du profit total
total_profit = sales_df_copy['Profit'].sum()
print(f"Profit total : {total_profit:.2f} MAD")
# Out:
# Profit total : 57789142.91 MAD

# %% [markdown]
# <h2>Total Profit PY</h2>

# %%
  #Calcul du profit par année
# Regroupement des données par année et sommation du profit pour chaque année
profit_by_year = sales_df_copy.groupby('Year')['Profit'].sum().reset_index()

# Affichage du profit par année
print("Profit par année :")
print(profit_by_year)

# Vérification si on a des données pour au moins 2 années de profit
if len(profit_by_year) >= 2:
    # Si oui, on récupère le profit de l'année en cours (dernière ligne)
    current_profit = profit_by_year.iloc[-1]['Profit']
    # Et le profit de l'année précédente (avant-dernière ligne)
    prev_profit = profit_by_year.iloc[-2]['Profit']
else:
    # Sinon, on définit le profit de l'année en cours comme étant celui de l'ensemble des profits
    current_profit = total_profit
    # Et l'année précédente comme étant zéro (pas de données pour l'année précédente)
    prev_profit = 0
# Out:
# Profit par année :
#    Year        Profit
# 0  2017  1.967777e+07
# 1  2018  1.978919e+07
# 2  2019  1.832218e+07

# %% [markdown]
# <h2>Total Profit/PY Var </h2>

# %%
# Calcul de la différence de profit entre l'année en cours et l'année précédente
profit_diff = current_profit - prev_profit
# Affichage de la différence de profit
print(f"Différence profit : {profit_diff:.2f} MAD")
# Out:
# Différence profit : -1467008.35 MAD

# %% [markdown]
# <h2>Total Profit/PY Var % </h2>

# %%
# Calcul de la variation en pourcentage du profit
# On évite la division par zéro en vérifiant si le profit de l'année précédente est différent de zéro
if prev_profit != 0:
    profit_var_pct = (profit_diff / prev_profit) * 100
else:
    profit_var_pct = 0

# Affichage de la variation en pourcentage du profit par rapport à l'année précédente
print(f"Variation % du profit YOY : {profit_var_pct:.2f}%")
# Out:
# Variation % du profit YOY : -7.41%

# %% [markdown]
# <h2>Profit Margin % </h2>

# %%
#  Calcul de la marge bénéficiaire en pourcentage
# On évite la division par zéro en vérifiant si le total des ventes n'est pas zéro
if total_sales != 0:
    profit_margin_pct = (total_profit / total_sales) * 100
else:
    profit_margin_pct = 0

# Affichage de la marge bénéficiaire
print(f"Marge bénéficiaire : {profit_margin_pct:.2f}%")
# Out:
# Marge bénéficiaire : 37.39%

# %% [markdown]
# <h2>Total Cost</h2>

# %%
# Calcul du coût total
total_cost = sales_df_copy['Cost'].sum()
print(f"Coût total : {total_cost:.2f} MAD")
# Out:
# Coût total : 96783997.69 MAD

# %% [markdown]
# <h2>Order Quantity vs Previous Year</h2>

# %%
# Vérification si on a des données pour au moins 2 années de commandes
if len(orders_by_year) >= 2:
    # Si oui, on récupère la quantité commandée de l'année en cours (dernière ligne)
    current_orders = orders_by_year.iloc[-1]['Order_Quantity']
    # Et la quantité commandée de l'année précédente (avant-dernière ligne)
    prev_orders = orders_by_year.iloc[-2]['Order_Quantity']
else:
    # Sinon, on définit la quantité commandée de l'année en cours comme étant celle de l'ensemble des commandes
    current_orders = total_orders
    # Et l'année précédente comme étant zéro (pas de données pour l'année précédente)
    prev_orders = 0
# 1. Variation brute des commandes
orders_diff = current_orders - prev_orders  # Calcul de la variation brute entre les commandes actuelles et les commandes précédentes

# 2. Variation en pourcentage
if prev_orders != 0:  # Vérifie si les commandes précédentes ne sont pas nulles
    orders_diff_pct = (orders_diff / prev_orders) * 100  # Calcul de la variation en pourcentage
else:
    orders_diff_pct = 0  # Si les commandes précédentes sont nulles, la variation est considérée comme 0%

# 3. Affichage de la variation des commandes
print(f"Variation commandes : {orders_diff} commandes, soit {orders_diff_pct:.2f}%")  # Affiche la variation brute et en pourcentage des commandes
# Out:
# Variation commandes : -1779 commandes, soit -7.68%

# %% [markdown]
# <h2>Développer les visuels </h2>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Pour affichage correct dans les notebooks
# %matplotlib inline

# %% [markdown]
# <h2>Ventes par produit et comparaison avec l’année précédente</h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Group by Product and Year
sales_product_year = sales_df_copy.groupby(['Product_Name', 'Year'])['Sales'].sum().reset_index()

# Pivot to get one column for each year's sales
pivot_df = sales_product_year.pivot(index='Product_Name', columns='Year', values='Sales').fillna(0)

# Sort products by current year sales (last column)
pivot_df = pivot_df.sort_values(by=pivot_df.columns[-1], ascending=False)

# Extract current and previous year (last and second-last column)
current_year = pivot_df.columns[-1]
prev_year = pivot_df.columns[-2] if len(pivot_df.columns) >= 2 else None

# Plot setup
plt.figure(figsize=(14, 6))

bar_width = 0.4
x = range(len(pivot_df))

# Bar: Previous Year (Red)
plt.bar([i - bar_width/2 for i in x], pivot_df[prev_year], width=bar_width, label=f'Sales {prev_year}', color='red')

# Bar: Current Year (Green)
plt.bar([i + bar_width/2 for i in x], pivot_df[current_year], width=bar_width, label=f'Sales {current_year}', color='green')

# Dotted Line: Previous Year
plt.plot(x, pivot_df[prev_year], color='black', linestyle='--', marker='o', label=f'{prev_year} Line')

# Labels and formatting
plt.xticks(x, pivot_df.index, rotation=45)
plt.ylabel('Sales')
plt.title('Sales CY vs Sales PY by Product')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2>Ventes par mois et comparaison avec l’année précédente</h2>

# %%
# Group sales by Month and Year
sales_month_year = sales_df_copy.groupby(['Month','Month_Name', 'Year'])['Sales'].sum().reset_index()
pivot_month = sales_month_year.pivot(index='Month_Name', columns='Year', values='Sales').fillna(0)
pivot_month = pivot_month.sort_index()

# Extract years
current_year = pivot_month.columns[-1]
prev_year = pivot_month.columns[-2]

# Plot
plt.figure(figsize=(12, 6))
x = range(1, 13)
plt.bar([i - bar_width/2 for i in x], pivot_month[prev_year], width=bar_width, color='red', label=f'Sales {prev_year}')
plt.bar([i + bar_width/2 for i in x], pivot_month[current_year], width=bar_width, color='green', label=f'Sales {current_year}')
plt.plot(x, pivot_month[prev_year], color='black', linestyle='--', marker='o', label=f'{prev_year} Line')

plt.xticks(x, [f'{i:02d}' for i in x])
plt.title('Sales CY vs Sales PY by Month')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2>Top 5 villes avec le plus de ventes</h2>

# %%
# Donut Chart
# Top 5 cities by total sales
top_cities = sales_df_copy.groupby('City')['Sales'].sum().nlargest(5)

plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(
    top_cities,
    labels=top_cities.index,
    autopct='%1.1f%%',
    startangle=90,
    textprops=dict(color="black")
)

# Add white circle in center for donut effect
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title("Sales by City")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2> Comparaison du bénéfice par canal de vente (channel)</h2>

# %%
# Bénéfices par canal et année
profit_channel_year = sales_df_copy.groupby(['Channel', 'Year'])['Profit'].sum().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(data=profit_channel_year, x='Channel', y='Profit', hue='Year')
plt.title("Comparaison du profit par canal de vente")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2>Top 5 clients par ventes, avec comparaison à l’année précédente</h2>

# %%
 #Top 5 customers
sales_df_copy = sales_df_copy.loc[:, ~sales_df_copy.columns.duplicated()]

client_sales = sales_df_copy.groupby(['Customer_Name', 'Year'])['Sales'].sum().reset_index()
top_customers = (
    client_sales[client_sales['Year'] == current_year]
    .nlargest(5, 'Sales')
    .Customer_Name
)

plt.figure(figsize=(10, 5))
sns.barplot(
    data=client_sales[client_sales['Customer_Name'].isin(top_customers)],
    x='Sales', y='Customer_Name', hue='Year', orient='h'
)
plt.title("Sales et Sales PY par Customer Names (Top 5)")
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2>Last 5 clients (ceux qui achètent le moins)</h2>

# %%
# Bottom 5 customers
last_customers = (
    client_sales[client_sales['Year'] == current_year]
    .nsmallest(5, 'Sales')
    .Customer_Name
)

plt.figure(figsize=(10, 5))
sns.barplot(
    data=client_sales[client_sales['Customer_Name'].isin(last_customers)],
    x='Sales', y='Customer_Name', hue='Year', orient='h'
)
plt.title("Sales et Sales PY par Customer Names (Bottom 5)")
plt.tight_layout()
plt.show()
